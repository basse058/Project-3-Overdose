# %%
import pandas as pd
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = "VSRR_Provisional_Drug_Overdose_Death_Counts.csv"

# %%
#dropped erroneous columns.
data_df = pd.read_csv(data)
data_df = pd.DataFrame(data_df.rename(columns={"State Name":"state_name", "Data Value":"value", "State":"state", "Year":"year", "Month":"month", "Indicator":"indicator"}))
data_df = data_df[["state", "year", "month", "indicator", "value", "state_name"]]
data_df
# Out:
#       state  year  month                                          indicator  \
# 0        AK  2015  April  Natural & semi-synthetic opioids, incl. methad...
# 1        AK  2015  April                        Opioids (T40.0-T40.4,T40.6)
# 2        AK  2015  April           Natural & semi-synthetic opioids (T40.2)
# 3        AK  2015  April                                  Methadone (T40.3)
# 4        AK  2015  April                                     Heroin (T40.1)
# ...     ...   ...    ...                                                ...
# 54367    YC  2022    May      Psychostimulants with abuse potential (T43.6)
# 54368    YC  2022    May                       Percent with drugs specified
# 54369    YC  2022    May                        Opioids (T40.0-T40.4,T40.6)
# 54370    YC  2022    May           Natural & semi-synthetic opioids (T40.2)
# 54371    YC  2022    May                     Number of Drug Overdose Deaths
#
#              value     state_name
# 0              NaN         Alaska
# 1              NaN         Alaska
# 2              NaN         Alaska
# 3              NaN         Alaska
# 4              NaN         Alaska
# ...            ...            ...
# 54367          218  New York City
# 54368  99.54640614  New York City
# 54369        2,438  New York City
# 54370          479  New York City
# 54371        2,866  New York City
#
# [54372 rows x 6 columns]

# %%
#dropped non-states from dataset.
list01 = ["New York City","United States"]
data_df = (data_df[data_df.state_name.isin(list01) == False])
data_df
# Out:
#       state  year  month                                          indicator  \
# 0        AK  2015  April  Natural & semi-synthetic opioids, incl. methad...
# 1        AK  2015  April                        Opioids (T40.0-T40.4,T40.6)
# 2        AK  2015  April           Natural & semi-synthetic opioids (T40.2)
# 3        AK  2015  April                                  Methadone (T40.3)
# 4        AK  2015  April                                     Heroin (T40.1)
# ...     ...   ...    ...                                                ...
# 53263    WY  2022    May      Psychostimulants with abuse potential (T43.6)
# 53264    WY  2022    May                       Percent with drugs specified
# 53265    WY  2022    May                        Opioids (T40.0-T40.4,T40.6)
# 53266    WY  2022    May           Natural & semi-synthetic opioids (T40.2)
# 53267    WY  2022    May                     Number of Drug Overdose Deaths
#
#              value state_name
# 0              NaN     Alaska
# 1              NaN     Alaska
# 2              NaN     Alaska
# 3              NaN     Alaska
# 4              NaN     Alaska
# ...            ...        ...
# 53263           50    Wyoming
# 53264  99.11504425    Wyoming
# 53265           69    Wyoming
# 53266           28    Wyoming
# 53267          113    Wyoming
#
# [52164 rows x 6 columns]

# %%
#Dropped missing values.
new_df = data_df.dropna()
#new_df = pd.DataFrame(new_df.rename(columns={"State_name":"State"}))
new_df
# Out:
#       state  year   month                                      indicator  \
# 5        AK  2015   April                 Number of Drug Overdose Deaths
# 6        AK  2015   April                               Number of Deaths
# 10       AK  2015   April                   Percent with drugs specified
# 16       AK  2015  August                   Percent with drugs specified
# 19       AK  2015  August                               Number of Deaths
# ...     ...   ...     ...                                            ...
# 53263    WY  2022     May  Psychostimulants with abuse potential (T43.6)
# 53264    WY  2022     May                   Percent with drugs specified
# 53265    WY  2022     May                    Opioids (T40.0-T40.4,T40.6)
# 53266    WY  2022     May       Natural & semi-synthetic opioids (T40.2)
# 53267    WY  2022     May                 Number of Drug Overdose Deaths
#
#              value state_name
# 5              126     Alaska
# 6            4,133     Alaska
# 10      88.0952381     Alaska
# 16     87.90322581     Alaska
# 19           4,222     Alaska
# ...            ...        ...
# 53263           50    Wyoming
# 53264  99.11504425    Wyoming
# 53265           69    Wyoming
# 53266           28    Wyoming
# 53267          113    Wyoming
#
# [42093 rows x 6 columns]

# %%
#create year/month dataframe
time_df = new_df.drop_duplicates(["year", "month"]).reset_index(drop=True)[["year", "month"]]
time_df = pd.DataFrame(time_df)
time_df
# Out:
#     year     month
# 0   2015     April
# 1   2015    August
# 2   2015  December
# 3   2015  February
# 4   2015   January
# ..   ...       ...
# 87  2022   January
# 88  2022      July
# 89  2022      June
# 90  2022     March
# 91  2022       May
#
# [92 rows x 2 columns]

# %%
#create state dataframe
state_df = new_df.drop_duplicates(["state"]).reset_index(drop=True)[["state"]]
state_df = pd.DataFrame(state_df)

# %%
#
od_death_data = new_df.loc[new_df['indicator'] == 'Number of Drug Overdose Deaths']
od_death_data.rename(columns={'value': 'overdose_deaths'}, inplace=True)
od_death_data['year'] = od_death_data['year'].astype(str)
od_death_data
# Out:
# C:\Users\basse\AppData\Local\Temp\ipykernel_13976\2958232274.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_death_data.rename(columns={'value': 'overdose_deaths'}, inplace=True)
# C:\Users\basse\AppData\Local\Temp\ipykernel_13976\2958232274.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_death_data['year'] = od_death_data['year'].astype(str)
#       state  year     month                       indicator overdose_deaths  \
# 5        AK  2015     April  Number of Drug Overdose Deaths             126
# 22       AK  2015    August  Number of Drug Overdose Deaths             124
# 25       AK  2015  December  Number of Drug Overdose Deaths             121
# 46       AK  2015  February  Number of Drug Overdose Deaths             127
# 59       AK  2015   January  Number of Drug Overdose Deaths             126
# ...     ...   ...       ...                             ...             ...
# 53214    WY  2022   January  Number of Drug Overdose Deaths             106
# 53225    WY  2022      July  Number of Drug Overdose Deaths             115
# 53243    WY  2022      June  Number of Drug Overdose Deaths             112
# 53251    WY  2022     March  Number of Drug Overdose Deaths             115
# 53267    WY  2022       May  Number of Drug Overdose Deaths             113
#
#       state_name
# 5         Alaska
# 22        Alaska
# 25        Alaska
# 46        Alaska
# 59        Alaska
# ...          ...
# 53214    Wyoming
# 53225    Wyoming
# 53243    Wyoming
# 53251    Wyoming
# 53267    Wyoming
#
# [4692 rows x 6 columns]

# %%
od_death_data["Date_Month_Year"] = od_death_data["month"] + " " + od_death_data["year"]
# Now we will parse the Date so that the notebook can read it as an actual date
import datetime
od_death_data['date'] = pd.to_datetime(od_death_data['Date_Month_Year'], format="%B %Y")
od_death_data
# Out:
# C:\Users\basse\AppData\Local\Temp\ipykernel_13976\2375321682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_death_data["Date_Month_Year"] = od_death_data["month"] + " " + od_death_data["year"]
# C:\Users\basse\AppData\Local\Temp\ipykernel_13976\2375321682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   od_death_data['date'] = pd.to_datetime(od_death_data['Date_Month_Year'], format="%B %Y")
#       state  year     month                       indicator overdose_deaths  \
# 5        AK  2015     April  Number of Drug Overdose Deaths             126
# 22       AK  2015    August  Number of Drug Overdose Deaths             124
# 25       AK  2015  December  Number of Drug Overdose Deaths             121
# 46       AK  2015  February  Number of Drug Overdose Deaths             127
# 59       AK  2015   January  Number of Drug Overdose Deaths             126
# ...     ...   ...       ...                             ...             ...
# 53214    WY  2022   January  Number of Drug Overdose Deaths             106
# 53225    WY  2022      July  Number of Drug Overdose Deaths             115
# 53243    WY  2022      June  Number of Drug Overdose Deaths             112
# 53251    WY  2022     March  Number of Drug Overdose Deaths             115
# 53267    WY  2022       May  Number of Drug Overdose Deaths             113
#
#       state_name Date_Month_Year       date
# 5         Alaska      April 2015 2015-04-01
# 22        Alaska     August 2015 2015-08-01
# 25        Alaska   December 2015 2015-12-01
# 46        Alaska   February 2015 2015-02-01
# 59        Alaska    January 2015 2015-01-01
# ...          ...             ...        ...
# 53214    Wyoming    January 2022 2022-01-01
# 53225    Wyoming       July 2022 2022-07-01
# 53243    Wyoming       June 2022 2022-06-01
# 53251    Wyoming      March 2022 2022-03-01
# 53267    Wyoming        May 2022 2022-05-01
#
# [4692 rows x 8 columns]

# %%
date_indexed_opioid_data = od_death_data.set_index('date')
# Taking a look
date_indexed_opioid_data.head()
# Out:
#            state  year     month                       indicator  \
# date
# 2015-04-01    AK  2015     April  Number of Drug Overdose Deaths
# 2015-08-01    AK  2015    August  Number of Drug Overdose Deaths
# 2015-12-01    AK  2015  December  Number of Drug Overdose Deaths
# 2015-02-01    AK  2015  February  Number of Drug Overdose Deaths
# 2015-01-01    AK  2015   January  Number of Drug Overdose Deaths
#
#            overdose_deaths state_name Date_Month_Year
# date
# 2015-04-01             126     Alaska      April 2015
# 2015-08-01             124     Alaska     August 2015
# 2015-12-01             121     Alaska   December 2015
# 2015-02-01             127     Alaska   February 2015
# 2015-01-01             126     Alaska    January 2015

# %%
od_death_data.to_csv('od_data_df.csv', index=True)
date_indexed_opioid_data.to_csv('od_index_data_df.csv', index=True)

# %%
#
death_data = new_df.loc[new_df['Indicator'] == 'Number of Deaths']
death_data.rename(columns={'Value': 'Total_deaths'}, inplace=True)
death_data['Year'] = death_data['Year'].astype(str)
death_data
# Out:
# C:\Users\basse\AppData\Local\Temp\ipykernel_5332\3124723358.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_data.rename(columns={'Value': 'Total_deaths'}, inplace=True)
# C:\Users\basse\AppData\Local\Temp\ipykernel_5332\3124723358.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_data['Year'] = death_data['Year'].astype(str)
#       State  Year     Month         Indicator Total_deaths State_name
# 6        AK  2015     April  Number of Deaths        4,133     Alaska
# 19       AK  2015    August  Number of Deaths        4,222     Alaska
# 28       AK  2015  December  Number of Deaths        4,193     Alaska
# 39       AK  2015  February  Number of Deaths        4,084     Alaska
# 49       AK  2015   January  Number of Deaths        4,034     Alaska
# ...     ...   ...       ...               ...          ...        ...
# 53211    WY  2022   January  Number of Deaths        5,984    Wyoming
# 53222    WY  2022      July  Number of Deaths        6,142    Wyoming
# 53236    WY  2022      June  Number of Deaths        6,127    Wyoming
# 53244    WY  2022     March  Number of Deaths        6,072    Wyoming
# 53259    WY  2022       May  Number of Deaths        6,155    Wyoming
#
# [4600 rows x 6 columns]

# %%
death_data["Date_Month_Year"] = death_data["Month"] + " " + death_data["Year"]
# Now we will parse the Date so that the notebook can read it as an actual date
import datetime
death_data['Date'] = pd.to_datetime(death_data['Date_Month_Year'], format="%B %Y")
death_data
# Out:
# C:\Users\basse\AppData\Local\Temp\ipykernel_5332\2051176313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_data["Date_Month_Year"] = death_data["Month"] + " " + death_data["Year"]
# C:\Users\basse\AppData\Local\Temp\ipykernel_5332\2051176313.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_data['Date'] = pd.to_datetime(death_data['Date_Month_Year'], format="%B %Y")
#       State  Year     Month         Indicator Total_deaths State_name  \
# 6        AK  2015     April  Number of Deaths        4,133     Alaska
# 19       AK  2015    August  Number of Deaths        4,222     Alaska
# 28       AK  2015  December  Number of Deaths        4,193     Alaska
# 39       AK  2015  February  Number of Deaths        4,084     Alaska
# 49       AK  2015   January  Number of Deaths        4,034     Alaska
# ...     ...   ...       ...               ...          ...        ...
# 53211    WY  2022   January  Number of Deaths        5,984    Wyoming
# 53222    WY  2022      July  Number of Deaths        6,142    Wyoming
# 53236    WY  2022      June  Number of Deaths        6,127    Wyoming
# 53244    WY  2022     March  Number of Deaths        6,072    Wyoming
# 53259    WY  2022       May  Number of Deaths        6,155    Wyoming
#
#       Date_Month_Year       Date
# 6          April 2015 2015-04-01
# 19        August 2015 2015-08-01
# 28      December 2015 2015-12-01
# 39      February 2015 2015-02-01
# 49       January 2015 2015-01-01
# ...               ...        ...
# 53211    January 2022 2022-01-01
# 53222       July 2022 2022-07-01
# 53236       June 2022 2022-06-01
# 53244      March 2022 2022-03-01
# 53259        May 2022 2022-05-01
#
# [4600 rows x 8 columns]

# %%
date_indexed_death_data = death_data.set_index('Date')
# Taking a look
date_indexed_death_data.head()
# Out:
#            State  Year     Month         Indicator Total_deaths State_name  \
# Date
# 2015-04-01    AK  2015     April  Number of Deaths        4,133     Alaska
# 2015-08-01    AK  2015    August  Number of Deaths        4,222     Alaska
# 2015-12-01    AK  2015  December  Number of Deaths        4,193     Alaska
# 2015-02-01    AK  2015  February  Number of Deaths        4,084     Alaska
# 2015-01-01    AK  2015   January  Number of Deaths        4,034     Alaska
#
#            Date_Month_Year
# Date
# 2015-04-01      April 2015
# 2015-08-01     August 2015
# 2015-12-01   December 2015
# 2015-02-01   February 2015
# 2015-01-01    January 2015

# %%
death_data.to_csv('../Resources/death_data_df.csv', index=True)
date_indexed_death_data.to_csv('../Resources/death_index.csv', index=False)

# %%
#
percent_data = new_df.loc[new_df['Indicator'] == 'Percent with drugs specified']
percent_data
# Out:
#        Year     Month                     Indicator        Value    State
# 10     2015     April  Percent with drugs specified   88.0952381   Alaska
# 16     2015    August  Percent with drugs specified  87.90322581   Alaska
# 31     2015  December  Percent with drugs specified  89.25619835   Alaska
# 47     2015  February  Percent with drugs specified  88.97637795   Alaska
# 55     2015   January  Percent with drugs specified  89.68253968   Alaska
# ...     ...       ...                           ...          ...      ...
# 53218  2022   January  Percent with drugs specified  99.05660377  Wyoming
# 53230  2022      July  Percent with drugs specified  99.13043478  Wyoming
# 53234  2022      June  Percent with drugs specified  99.10714286  Wyoming
# 53254  2022     March  Percent with drugs specified  99.13043478  Wyoming
# 53264  2022       May  Percent with drugs specified  99.11504425  Wyoming
#
# [4600 rows x 5 columns]

# %%
time_df.to_csv('Resources/time_df.csv', index=False)
state_df.to_csv('Resources/state_df.csv', index=False)
od_death_data.to_csv('Resources/od_death_data_df.csv', index=False)
death_data.to_csv('Resources/death_data_df.csv', index=False)
percent_data.to_csv('Resources/percent_df.csv', index=False)
